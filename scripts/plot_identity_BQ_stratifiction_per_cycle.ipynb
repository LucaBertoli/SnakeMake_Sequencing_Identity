# %%
#### FILTRAGGIO VARIANTI GIAB
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_cycle_elm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/old_thesis_results/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat_cycle.by_cycle_only.tsv", delimiter="\t")
# df_cycle_gm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle.by_cycle_only.tsv", delimiter="\t")
df_cycle_gm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_ns = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle.by_cycle_only.tsv", delimiter="\t")
# df_cycle_MGI = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_MGI = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")

df_cycle_elm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/old_thesis_results/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat_cycle_read1.by_cycle_only.tsv", delimiter="\t")
# df_cycle_gm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read1.by_cycle_only.tsv", delimiter="\t")
df_cycle_gm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_ns_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle_read1.by_cycle_only.tsv", delimiter="\t")
# df_cycle_MGI_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_cycle_only.tsv", delimiter="\t")
df_cycle_MGI_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_elm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/old_thesis_results/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat_cycle_read2.by_cycle_only.tsv", delimiter="\t")
# df_cycle_gm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read2.by_cycle_only.tsv", delimiter="\t")
df_cycle_gm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_ns_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle_read2.by_cycle_only.tsv", delimiter="\t")
# df_cycle_MGI_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_cycle_only.tsv", delimiter="\t")
df_cycle_MGI_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")

df_elm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/old_thesis_results/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat_cycle.by_NEW_bin_cycle.tsv", delimiter="\t")
# df_gm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle.by_NEW_bin_cycle.tsv", delimiter="\t")
df_gm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_ns = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle.by_NEW_bin_cycle.tsv", delimiter="\t")
# df_mgi= pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_mgi= pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")

df_tot_elm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/old_thesis_results/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat_cycle.by_quality_cycle.tsv", delimiter="\t")
# df_tot_gm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle.by_quality_cycle.tsv", delimiter="\t")
df_tot_gm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv", delimiter="\t")
df_tot_ns = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle.by_quality_cycle.tsv", delimiter="\t")
# df_tot_mgi=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv", delimiter="\t")
df_tot_mgi=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv", delimiter="\t")

df_tot_noBin_elm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/old_thesis_results/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat_cycle_read1.by_quality_cycle.tsv", delimiter="\t")
# df_tot_noBin_gm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read1.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_gm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_ns_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle_read1.by_quality_cycle.tsv", delimiter="\t")
# df_tot_noBin_mgi_R1=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_mgi_R1=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_elm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/old_thesis_results/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat_cycle_read2.by_quality_cycle.tsv", delimiter="\t")
# df_tot_noBin_gm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read2.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_gm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_ns_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle_read2.by_quality_cycle.tsv", delimiter="\t")
# df_tot_noBin_mgi_R2=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_mgi_R2=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv", delimiter="\t")

df_tot_elm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/old_thesis_results/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat_cycle_read1.by_NEW_bin_cycle.tsv", delimiter="\t")
# df_tot_gm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read1.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_gm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_ns_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle_read1.by_NEW_bin_cycle.tsv", delimiter="\t")
# df_tot_mgi_R1=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_mgi_R1=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_elm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/old_thesis_results/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat_cycle_read2.by_NEW_bin_cycle.tsv", delimiter="\t")
# df_tot_gm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read2.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_gm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_ns_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle_read2.by_NEW_bin_cycle.tsv", delimiter="\t")
# df_tot_mgi_R2=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_mgi_R2=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")


colori_matplotlib = [
    "r", "b", "g", "c", "m", "y", "k",
    "royalblue", "limegreen", "tomato", "deepskyblue", "darkorchid", "goldenrod", "dimgray",
    "dodgerblue", "springgreen", "salmon", "skyblue", "mediumorchid", "khaki", "lightgray",
    "cornflowerblue", "palegreen", "lightcoral", "lightcyan", "lightpink", "lightyellow", "silver",
    "steelblue", "springgreen", "lightsalmon", "powderblue", "mediumvioletred", "gold", "gainsboro",
    "cornflowerblue", "chartreuse", "darkorange", "cadetblue", "mediumslateblue", "darkkhaki", "beige",
    "mediumblue", "mediumseagreen", "crimson", "darkturquoise", "darkslategray", "olive", "floralwhite",
    "mediumslateblue", "chartreuse", "darkorange", "cadetblue", "mediumslateblue", "darkkhaki", "beige",
]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[49], line 10
#       8 # df_cycle_gm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle.by_cycle_only.tsv", delimiter="\t")
#       9 df_cycle_gm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
# ---> 10 df_cycle_ns = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle.by_cycle_only.tsv", delimiter="\t")
# ...

# %%
#### FILTRAGGIO VARIANTI GATK
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_cycle_elm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_gm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_ns = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_MGI = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_cycle.tsv.by_cycle_only.tsv", delimiter="\t")

df_cycle_elm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_gm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_ns_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_MGI_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_elm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_gm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_ns_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_MGI_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_cycle.tsv.by_cycle_only.tsv", delimiter="\t")

df_elm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_bin_cycle.tsv", delimiter="\t")
df_gm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_bin_cycle.tsv", delimiter="\t")
df_ns = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_bin_cycle.tsv", delimiter="\t")
df_mgi= pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_bin_cycle.tsv", delimiter="\t")

df_tot_elm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_cycle.tsv", delimiter="\t")
df_tot_gm = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_cycle.tsv", delimiter="\t")
df_tot_ns = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_cycle.tsv", delimiter="\t")
df_tot_mgi=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_cycle.tsv", delimiter="\t")

df_tot_noBin_elm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_cycle.tsv", delimiter="\t")
df_tot_noBin_gm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_cycle.tsv", delimiter="\t")
df_tot_noBin_ns_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_cycle.tsv", delimiter="\t")
df_tot_noBin_mgi_R1=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_cycle.tsv", delimiter="\t")
df_tot_noBin_elm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_cycle.tsv", delimiter="\t")
df_tot_noBin_gm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_cycle.tsv", delimiter="\t")
df_tot_noBin_ns_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_cycle.tsv", delimiter="\t")
df_tot_noBin_mgi_R2=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_cycle.tsv", delimiter="\t")

df_tot_elm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_bin_cycle.tsv", delimiter="\t")
df_tot_gm_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_bin_cycle.tsv", delimiter="\t")
df_tot_ns_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_bin_cycle.tsv", delimiter="\t")
df_tot_mgi_R1=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_bin_cycle.tsv", delimiter="\t")
df_tot_elm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_bin_cycle.tsv", delimiter="\t")
df_tot_gm_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_bin_cycle.tsv", delimiter="\t")
df_tot_ns_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_bin_cycle.tsv", delimiter="\t")
df_tot_mgi_R2=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_bin_cycle.tsv", delimiter="\t")


# colori_matplotlib = [
#     "r", "b", "g", "c", "m", "y", "k",
#     "royalblue", "limegreen", "tomato", "deepskyblue", "darkorchid", "goldenrod", "dimgray",
#     "dodgerblue", "springgreen", "salmon", "skyblue", "mediumorchid", "khaki", "lightgray",
#     "cornflowerblue", "palegreen", "lightcoral", "lightcyan", "lightpink", "lightyellow", "silver",
#     "steelblue", "springgreen", "lightsalmon", "powderblue", "mediumvioletred", "gold", "gainsboro",
#     "cornflowerblue", "chartreuse", "darkorange", "cadetblue", "mediumslateblue", "darkkhaki", "beige",
#     "mediumblue", "mediumseagreen", "crimson", "darkturquoise", "darkslategray", "olive", "floralwhite",
#     "mediumslateblue", "chartreuse", "darkorange", "cadetblue", "mediumslateblue", "darkkhaki", "beige",
# ]
colori_matplotlib = [
    "#004488", "#E69F00", "#009E73", "#CC79A7"
]

# %%
# tech_dfs = {
#     "Illumina NovaSeq X": df_tot_ns,
#     "Element AVITI": df_tot_elm,
#     "GeneMind SurfSeq 5000": df_tot_gm,
#     "MGI T1": df_tot_mgi
# }

# tech_dfs_1 = {
#     "Illumina NovaSeq X": df_tot_noBin_ns_R1,
#     "Element AVITI": df_tot_noBin_elm_R1,
#     "GeneMind SurfSeq 5000": df_tot_noBin_gm_R1,
#     "MGI T1": df_tot_noBin_mgi_R1
# }

# tech_dfs_2 = {
#     "Illumina NovaSeq X": df_tot_noBin_ns_R2,
#     "Element AVITI": df_tot_noBin_elm_R2,
#     "GeneMind SurfSeq 5000": df_tot_noBin_gm_R2,
#     "MGI T1": df_tot_noBin_mgi_R2
# }

tech_dfs = {
    "V1": pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle.by_quality_cycle.tsv", delimiter="\t"),
    "V2": pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_all_cycle.tsv", delimiter="\t")
}

tech_dfs_1 = {
    "V1": pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read1.by_quality_cycle.tsv", delimiter="\t"),
    "V2": pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_cycle.tsv", delimiter="\t")
}

tech_dfs_2 = {
    "V1": pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read2.by_quality_cycle.tsv", delimiter="\t"),
    "V2": pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_cycle.tsv", delimiter="\t")
}

tutti_tech_dfs = [tech_dfs, tech_dfs_1, tech_dfs_2]

## PLOT SEPARATI
# for i, dfs in enumerate(tutti_tech_dfs):

#     if i == 0:
#         mode = ""
#     elif i == 1:
#         mode = " Read 1"
#     else:
#         mode = " Read 2"

#     print(f"Plot gruppo {i}{mode}")

#     # --- CALCOLA QUALITÀ MEDIA PER CICLO ---
#     tech_cycle_quality = {}

#     for tech_name, df in dfs.items():

#         # Evita di modificare il dataframe originale
#         df_local = df.copy()

#         # Calcola totale basi
#         df_local["total_bases"] = df_local["match"] + df_local["mismatch"] + df_local["insertion"]

#         # Raggruppa per ciclo e calcola la media pesata del Qscore
#         grouped = (
#             df_local.groupby("Cycle", observed=False)
#                 .apply(lambda x: (
#                     -10 * np.log10(
#                         np.average(10 ** (-x["BaseQuality"] / 10), weights=x["total_bases"])
#                     )
#                     if x["total_bases"].sum() > 0 else np.nan
#                 ))
#                 .reset_index(name="mean_BaseQuality")
#         )

#         tech_cycle_quality[tech_name] = grouped

#     # --- PLOT ---
#     fig, ax = plt.subplots(figsize=(8, 5))

#     for j, (tech_name, grouped) in enumerate(tech_cycle_quality.items()):
#         ax.plot(
#             grouped["Cycle"],
#             grouped["mean_BaseQuality"],
#             label=tech_name,
#             color=colori_matplotlib[j % len(colori_matplotlib)],
#             linewidth=0.8,
#             marker='o',
#             markersize=2,
#             alpha=0.8
#         )

#     # Titolo
#     ax.set_title(
#         f"Sequencer-assigned Qscore per Cycle{mode} (logarithm of mean error probability)"
#     )

#     # Assi
#     ax.set_xlabel("Cycle")
#     ax.set_ylabel("Mean Qscore")
#     ax.grid(True, alpha=0.3)
#     ax.set_ylim(0, 43)

#     # Legenda globale sotto il grafico
#     fig.legend(
#         tech_cycle_quality.keys(),
#         loc="lower center",
#         ncol=len(tech_cycle_quality),
#         fontsize=10,
#         frameon=True
#     )

#     plt.tight_layout(rect=[0, 0.05, 1, 1])
#     plt.show()

# ===============================
# SEQUENCER-ASSIGNED QSCORE PER CYCLE (R1 + R2 CONCATENATI)
# ===============================

tech_dict = {
    "Illumina NovaSeq X": (df_tot_noBin_ns_R1, df_tot_noBin_ns_R2),
    "Element AVITI": (df_tot_noBin_elm_R1, df_tot_noBin_elm_R2),
    "GeneMind SurfSeq 5000": (df_tot_noBin_gm_R1, df_tot_noBin_gm_R2),
    "MGI T1": (df_tot_noBin_mgi_R1, df_tot_noBin_mgi_R2)
}

# tech_dict = {
#     "V1": (pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read1.by_quality_cycle.tsv", delimiter="\t"), pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read2.by_quality_cycle.tsv", delimiter="\t")),
#     "V2": (pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_cycle.tsv", delimiter="\t"), pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_cycle.tsv", delimiter="\t"))
# }

fig, ax = plt.subplots(figsize=(10, 5))

for j, (tech_name, (df_r1, df_r2)) in enumerate(tech_dict.items()):

    # --- R1 ---
    df1 = df_r1.copy()
    df1["total_bases"] = df1["match"] + df1["mismatch"] + df1["insertion"]

    q_r1 = (
        df1.groupby("Cycle")
        .apply(lambda x: (
            -10 * np.log10(
                np.average(
                    10 ** (-x["BaseQuality"] / 10),
                    weights=x["total_bases"]
                )
            )
            if x["total_bases"].sum() > 0 else np.nan
        ))
        .reset_index(name="mean_Qscore")
    )

    # --- R2 ---
    df2 = df_r2.copy()
    df2["total_bases"] = df2["match"] + df2["mismatch"] + df2["insertion"]

    # media corretta facendo la media dell'error rate sottostante
    q_r2 = (
        df2.groupby("Cycle")
        .apply(lambda x: (
            -10 * np.log10(
                np.average(
                    10 ** (-x["BaseQuality"] / 10),
                    weights=x["total_bases"]
                )
            )
            if x["total_bases"].sum() > 0 else np.nan
        ))
        .reset_index(name="mean_Qscore")
    )

    ## media aritmetica Q score
    # q_r2 = (df2.groupby("Cycle").apply(lambda x: (np.average(x["BaseQuality"], weights=x["total_bases"])) if x["total_bases"].sum() > 0 else np.nan)).reset_index(name="mean_Qscore")
    # q_r1 = (df1.groupby("Cycle").apply(lambda x: (np.average(x["BaseQuality"], weights=x["total_bases"])) if x["total_bases"].sum() > 0 else np.nan)).reset_index(name="mean_Qscore")

    # shift cicli R2
    q_r2["Cycle"] += 151   # tipicamente 150

    # concat R1 + R2
    q_concat = pd.concat([q_r1, q_r2], ignore_index=True)
    rolling_average = q_concat["mean_Qscore"].rolling(window=5, min_periods=1, center=True).mean() #center=True

    ax.plot(
        q_concat["Cycle"],
        q_concat["mean_Qscore"],
        label=tech_name,
        color=colori_matplotlib[j % len(colori_matplotlib)],
        linewidth=0.8,
        marker="o",
        markersize=2,
        alpha=0.8
    )

# separatore R1 / R2
ax.axvline(
    x=150,
    linestyle="--",
    linewidth=1,
    color="gray",
    alpha=0.3
)

# --- FORMATTAZIONE ---
ax.set_title("Sequencer-assigned Qscore per Cycle (R1 + R2)")
ax.set_xlabel("Cycle")
ax.set_ylabel("Mean Qscore")
ax.grid(True, alpha=0.3)
ax.set_ylim(15, 43)

ax.legend(title="Technology", fontsize=10, frameon=True)

plt.tight_layout()
plt.show()

# %%
# Tre gruppi di dataframe
tech_dfs_0 = {
    "Illumina NovaSeq X": df_cycle_ns,
    "Element AVITI": df_cycle_elm,
    "GeneMind SurfSeq 5000": df_cycle_gm,
    "MGI T1": df_cycle_MGI
}

tech_dfs_1 = {
    "Illumina NovaSeq X": df_cycle_ns_R1,
    "Element AVITI": df_cycle_elm_R1,
    "GeneMind SurfSeq 5000": df_cycle_gm_R1,
    "MGI T1": df_cycle_MGI_R1
}

tech_dfs_2 = {
    "Illumina NovaSeq X": df_cycle_ns_R2,
    "Element AVITI": df_cycle_elm_R2,
    "GeneMind SurfSeq 5000": df_cycle_gm_R2,
    "MGI T1": df_cycle_MGI_R2
}

# Lista dei gruppi
tutti_tech_dfs = [tech_dfs_0, tech_dfs_1, tech_dfs_2]

# Loop sui 3 insiemi
for i, dfs in enumerate(tutti_tech_dfs):

    # Titolo per la figura
    if i == 0:
        mode = ""
    elif i == 1:
        mode = " Read 1"
    else:
        mode = " Read 2"

    print(f"Plot Identity-based Qscore {mode}")

    # --- FIGURA ---
    fig, ax = plt.subplots(figsize=(8, 5))

    for j, (tech_name, tech_df) in enumerate(dfs.items()):

        # Evita di modificare i dataframe originali
        sub = tech_df.copy().sort_values("Cycle")

        if not sub.empty:
            # Conversione identity → Qscore
            qscore = -10 * np.log10(1 - sub["identity_with_ins_filtered"])

            ax.plot(
                sub["Cycle"],
                qscore,
                label=tech_name,
                color=colori_matplotlib[j % len(colori_matplotlib)],
                linewidth=0.8,
                marker='o',
                markersize=2,
                alpha=0.8
            )

    # Etichette e formattazione
    ax.set_title(f"Identity-based Qscore per Cycle{mode}")
    ax.set_xlabel("Cycle")
    ax.set_ylabel("Qscore")
    ax.grid(True, alpha=0.3)
    ax.set_ylim(0, 43)

    # Legenda sotto
    fig.legend(
        dfs.keys(),
        loc="lower center",
        ncol=len(dfs),
        fontsize=10,
        frameon=True
    )

    plt.tight_layout(rect=[0, 0.05, 1, 1])
    plt.show()
# Out:
# Plot Identity-based Qscore
# Plot Identity-based Qscore  Read 1
# Plot Identity-based Qscore  Read 2

# %%
#calcolo error rate (non identita)
 
# --- FIGURA UNICA ---
ns = [df_cycle_ns_R1, df_cycle_ns_R2] 
elm = [df_cycle_elm_R1, df_cycle_elm_R2] 
gm = [df_cycle_gm_R1, df_cycle_gm_R2] 
mgi = [df_cycle_MGI_R1, df_cycle_MGI_R2] 
tech_dict = { "Illumina": ns, "Element": elm, "GeneMind": gm, "MGI": mgi }

# V1 = [pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read1.by_cycle_only.tsv", delimiter="\t"), pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read2.by_cycle_only.tsv", delimiter="\t")] 
# V2 = [pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read1_cycle.tsv.by_cycle_only.tsv", delimiter="\t"), pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_read2_cycle.tsv.by_cycle_only.tsv", delimiter="\t")] 
# tech_dict = { "V1": V1, "V2": V2}

fig, ax = plt.subplots(figsize=(10, 5))

for j, (tech_name, tech_dfs) in enumerate(tech_dict.items()):

    # R1 e R2 separati (senza side effects)
    df_r1 = tech_dfs[0]
    df_r2 = tech_dfs[1].copy()
    df_r2["Cycle"] += 151   # tipicamente 150

    df_concat = pd.concat([df_r1, df_r2], ignore_index=True)
    # print(df_concat)

    # Conversione identity → error_rate
    error_rate = (1 - df_concat["identity_with_ins_filtered"]) * 100
    rolling_average = error_rate.rolling(window=5, min_periods=1, center=True).mean() #center=True

    ax.plot(
        df_concat["Cycle"],
        error_rate,
        label=tech_name,
        color=colori_matplotlib[j % len(colori_matplotlib)],
        linewidth=0.8,
        marker='o',
        markersize=2,
        alpha=0.8
    )
    ax.axvline(
        x=150,
        linestyle="--",
        linewidth=1,
        color="gray",
        alpha=0.2,
    )
# --- FORMATTAZIONE GLOBALE ---
ax.set_title("Error rate per Cycle (R1 + R2)")
ax.set_xlabel("Cycle")
ax.set_ylabel("Error rate (%)")
ax.grid(True, alpha=0.3)
ax.set_ylim(0, 1)

ax.legend(title="Technology", fontsize=10, frameon=True)

plt.tight_layout()
plt.show()

# %%
# Dizionario con i dataframe e il nome della tecnologia
tech_dfs = {
    "Illumina NovaSeq X": df_ns,
    "Element AVITI": df_elm,
    "GeneMind SurfSeq 5000": df_gm,
    "MGI T1": df_mgi
}
 
# Trova tutti i BQ_bin disponibili (assumendo che siano simili tra i dataframe)
all_bins = sorted(
    set().union(*[df["BQ_bin"].unique() for df in tech_dfs.values()]),
    key=lambda x: str(x)
)
print(all_bins)
 
# Crea una griglia 2x2 (uno per ciascun bin)
fig, ax = plt.subplots(1, 3, figsize=(15, 4))
axes = ax.flatten()
colors = plt.cm.tab10.colors  # una palette con colori distinti per le tecnologie
 
# Itera su ciascun BQ_bin
for i, quality in enumerate(all_bins[:4]):  # mostra i primi 4 bin (modificabile)
    ax_i = axes[i]
    for j, (tech_name, tech_df) in enumerate(tech_dfs.items()):
        sub = tech_df[tech_df["BQ_bin"] == quality].sort_values("Cycle")
        if not sub.empty:
            ax_i.plot(
                sub["Cycle"],
                sub["identity_with_ins_filtered"] * 100,
                label=tech_name,
                color=colori_matplotlib[j % len(colori_matplotlib)],
                # color=colors[j % len(colors)],
                linewidth=0.5,
                marker='o',
                markersize=2,
                alpha=0.7
            )
    ax_i.set_title(f"Sequencer Qscore {quality} bin")
    ax_i.set_xlabel("Cycle")
    ax_i.set_ylabel("Identity (%)")
    ax_i.grid(True, alpha=0.3)
    # Rimuoviamo le legende individuali
    # if quality=="3-17":
    #     ax_i.set_ylim(82, 100)
    # if quality=="18-29":
    #     ax_i.set_ylim(98.4, 100)
    # if quality=="30+":
    #     ax_i.set_ylim(99.9, 100)


# Crea una legenda unica in basso
fig.legend(
    tech_dfs.keys(),
    loc="lower center",
    ncol=len(tech_dfs),
    fontsize=10,
    frameon=True
)

# Migliora il layout complessivo
plt.tight_layout(rect=[0, 0.05, 1, 1])  # lascia più spazio per la legenda sotto
plt.show()
# Out:
# ['0-19', '20-29', '30+']

# %%
# Dizionario con i dataframe e il nome della tecnologia
tech_dfs = {
    "Illumina NovaSeq X": df_ns,
    "Element AVITI": df_elm,
    "GeneMind SurfSeq 5000": df_gm,
    "MGI T1": df_mgi
}
 
# Trova tutti i BQ_bin disponibili (assumendo che siano simili tra i dataframe)
all_bins = sorted(
    set().union(*[df["BQ_bin"].unique() for df in tech_dfs.values()]),
    key=lambda x: str(x)
)
 
# Crea una griglia 2x2 (uno per ciascun bin)
fig, ax = plt.subplots(1, 3, figsize=(15, 4))
axes = ax.flatten()
colors = plt.cm.tab10.colors  # una palette con colori distinti per le tecnologie
 
# Itera su ciascun BQ_bin
for i, quality in enumerate(all_bins[:4]):  # mostra i primi 4 bin (modificabile)
    ax_i = axes[i]
    for j, (tech_name, tech_df) in enumerate(tech_dfs.items()):
        sub = tech_df[tech_df["BQ_bin"] == quality].sort_values("Cycle")
        if not sub.empty:
            qscore = -10 * np.log10(1 - sub["identity_with_ins_filtered"])
            ax_i.plot(
                sub["Cycle"],
                qscore,
                label=tech_name,
                color=colori_matplotlib[j % len(colori_matplotlib)],
                # color=colors[j % len(colors)],
                linewidth=0.5,
                marker='o',
                markersize=2,
                alpha=0.7
            )
    ax_i.set_title(f"Sequencer Qscore {quality} bin")
    ax_i.set_xlabel("Cycle")
    ax_i.set_ylabel("Identity-based Qscore")
    ax_i.grid(True, alpha=0.3)
    # Rimuoviamo le legende individuali
    if quality=="0-19":
        ax_i.set_ylim(0, 19)
    if quality=="20-29":
        ax_i.set_ylim(20, 32)
    if quality=="30+":
        ax_i.set_ylim(30, 43)
    ax_i.set_ylim(0, 43)

# Crea una legenda unica in basso
fig.legend(
    tech_dfs.keys(),
    loc="lower center",
    ncol=len(tech_dfs),
    fontsize=10,
    frameon=True
)

# Migliora il layout complessivo
plt.tight_layout(rect=[0, 0.05, 1, 1])  # lascia spazio per la legenda sotto
plt.show()

# %%
# Dizionario con i dataframe e il nome della tecnologia
tech_dfs = {
    "Illumina NovaSeq X": df_ns,
    "Element AVITI": df_elm,
    "GeneMind SurfSeq 5000": df_gm,
    "MGI T1": df_mgi
}
 
# Trova tutti i BQ_bin disponibili (assumendo che siano simili tra i dataframe)
all_bins = sorted(
    set().union(*[df["BQ_bin"].unique() for df in tech_dfs.values()]),
    key=lambda x: str(x)
)

# --- FIGURA CON DUE RIGHE DI SUBPLOT (3 col x 2 righe) ---
fig, axes = plt.subplots(2, 3, figsize=(15, 8), sharex='col')
axes_qscore = axes[0]
axes_bases = axes[1]

for i, quality in enumerate(all_bins[:3]):  # usa i primi 3 bin
    ax_q = axes_qscore[i]
    ax_b = axes_bases[i]

    for j, (tech_name, tech_df) in enumerate(tech_dfs.items()):
        sub = tech_df[tech_df["BQ_bin"] == quality].sort_values("Cycle").copy()
        if not sub.empty:
            # Calcolo Qscore (basato su identità)
            qscore = -10 * np.log10(1 - sub["identity_with_ins_filtered"])

            # Numero totale di basi per ciclo
            num_bases = sub["match"] + sub["mismatch"] + sub["insertion"]

            # ✅ Normalizza sul totale di quella tecnologia e bin
            total_bases_bin = num_bases.sum()
            num_bases_norm = (num_bases / total_bases_bin)*100

            color = colori_matplotlib[j % len(colori_matplotlib)]

            # --- Riga superiore: Qscore (identità per ciclo) ---
            ax_q.plot(
                sub["Cycle"],
                qscore,
                label=tech_name,
                color=color,
                linewidth=0.8,
                marker='o',
                markersize=2,
                alpha=0.8
            )

            # --- Riga inferiore: frazione di basi normalizzata ---
            ax_b.plot(
                sub["Cycle"],
                num_bases_norm,
                color=color,
                linewidth=0.8,
                marker='^',
                markersize=3,
                alpha=0.6
            )

    # --- Etichette e titoli ---
    bin_titles = {
        "0-19": "Low Qscore",
        "20-29": "Medium Qscore",
        "30+": "High Qscore"
    }
    ax_q.set_title(bin_titles.get(quality, quality))
    ax_q.set_ylabel("Identity-based Qscore")
    ax_b.set_xlabel("Cycle")
    if quality == "0-19":
        ax_b.set_title(f"Low Qscore Bin ({quality})")
    elif quality == "20-29":
        ax_b.set_title(f"Medium Qscore Bin ({quality})")
    else:
        ax_b.set_title(f"High Qscore Bin ({quality})")
    ax_b.set_ylabel("Fraction of bases per cycle (%)")
    ax_q.grid(True, alpha=0.3)
    ax_b.grid(True, alpha=0.3)
    ax_b.set_ylim(0.1, 1.1)  # la somma totale del bin = 1

    # Range personalizzati per Qscore
    # if quality == "0-19":
    #     ax_q.set_ylim(0, 19)
    # elif quality == "20-29":
    #     ax_q.set_ylim(20, 32)
    # elif quality == "30+":
    #     ax_q.set_ylim(30, 43)
    # else:
    #     ax_q.set_ylim(0, 43)
    ax_q.set_ylim(0, 43)

# --- Legenda globale (solo Qscore) ---
lines, labels = [], []
for ax_i in axes_qscore:
    line, label = ax_i.get_legend_handles_labels()
    lines.extend(line)
    labels.extend(label)

fig.legend(
    lines[:len(tech_dfs)],
    labels[:len(tech_dfs)],
    loc="lower center",
    ncol=len(tech_dfs),
    fontsize=10,
    frameon=True,
)


plt.tight_layout(rect=[0, 0.05, 1, 1])
plt.show()

# %%
####normalizzazione per base
# Dizionario con i dataframe e il nome della tecnologia
tech_dfs = {
    "Illumina NovaSeq X": df_ns,
    "Element AVITI": df_elm,
    "GeneMind SurfSeq 5000": df_gm,
    "MGI T1": df_mgi
}
 
# Trova tutti i BQ_bin disponibili (assumendo che siano simili tra i dataframe)
all_bins = sorted(
    set().union(*[df["BQ_bin"].unique() for df in tech_dfs.values()]),
    key=lambda x: str(x)
)

# --- FIGURA CON DUE RIGHE DI SUBPLOT (3 col x 2 righe) ---
fig, axes = plt.subplots(2, 3, figsize=(15, 8), sharex='col')
axes_qscore = axes[0]
axes_bases = axes[1]

for i, quality in enumerate(all_bins[:3]):  # usa i primi 3 bin
    ax_q = axes_qscore[i]
    ax_b = axes_bases[i]

    for j, (tech_name, tech_df) in enumerate(tech_dfs.items()):
        sub = tech_df[tech_df["BQ_bin"] == quality].sort_values("Cycle").copy()
        if sub.empty:
            continue

        # Calcolo Qscore (basato su identità)
        qscore = -10 * np.log10(1 - sub["identity_with_ins_filtered"])

        # Numero di basi per ciclo per questo bin
        sub["num_bases"] = sub["match"] + sub["mismatch"] + sub["insertion"]

        # ✅ Normalizza per la somma totale di basi di *quel ciclo* nella stessa tecnologia
        # Otteniamo la somma per ciclo su tutto il dataframe della tecnologia
        total_bases_per_cycle = (
            tech_df.groupby("Cycle")[["match", "mismatch", "insertion"]]
            .sum()
            .sum(axis=1)   # somma match+mismatch+insertion
        )

        # Aggiunge la frazione normalizzata (%) rispetto al totale di quel ciclo
        sub["num_bases_norm"] = (
            sub.apply(lambda r: (r["num_bases"] / total_bases_per_cycle.loc[r["Cycle"]]) * 100, axis=1)
        )

        color = colori_matplotlib[j % len(colori_matplotlib)]

        # --- Riga superiore: Qscore (identità per ciclo) ---
        ax_q.plot(
            sub["Cycle"],
            qscore,
            label=tech_name,
            color=color,
            linewidth=0.8,
            marker='o',
            markersize=2,
            alpha=0.8
        )

        # --- Riga inferiore: frazione di basi normalizzata per ciclo ---
        ax_b.plot(
            sub["Cycle"],
            sub["num_bases_norm"],
            color=color,
            linewidth=0.8,
            marker='^',
            markersize=3,
            alpha=0.6
        )

    # --- Etichette e titoli ---
    ax_q.set_title(f"Sequencer Qscore {quality} bin")
    ax_q.set_ylabel("Identity-based Qscore")
    ax_b.set_xlabel("Cycle")
    ax_b.set_ylabel("Fraction of bases per cycle (%)")
    ax_q.grid(True, alpha=0.3)
    ax_b.grid(True, alpha=0.3)
    ax_q.set_ylim(0, 43)

# --- Legenda globale ---
lines, labels = [], []
for ax_i in axes_qscore:
    line, label = ax_i.get_legend_handles_labels()
    lines.extend(line)
    labels.extend(label)

fig.legend(
    lines[:len(tech_dfs)],
    labels[:len(tech_dfs)],
    loc="lower center",
    ncol=len(tech_dfs),
    fontsize=10,
    frameon=True,
)

plt.tight_layout(rect=[0, 0.05, 1, 1])
plt.show()

# %%
# Dizionario con i dataframe e il nome della tecnologia (R1 e R2)
R1 = {
    "Illumina NovaSeq X": df_tot_ns_R1,
    "Element AVITI": df_tot_elm_R1,
    "GeneMind SurfSeq 5000": df_tot_gm_R1,
    "MGI T1": df_tot_mgi_R1
}

R2 = {
    "Illumina NovaSeq X": df_tot_ns_R2,
    "Element AVITI": df_tot_elm_R2,
    "GeneMind SurfSeq 5000": df_tot_gm_R2,
    "MGI T1": df_tot_mgi_R2
}

for dfs in [R1, R2]:
    # Trova tutti i BQ_bin disponibili (assumendo che siano simili tra i dataframe)
    all_bins = sorted(
        set().union(*[df["BQ_bin"].unique() for df in dfs.values()]),
        key=lambda x: str(x)
    )
    
    # Crea una griglia 2x2 (uno per ciascun bin)
    fig, ax = plt.subplots(1, 3, figsize=(15, 4))
    axes = ax.flatten()
    colors = plt.cm.tab10.colors  # una palette con colori distinti per le tecnologie
    
    # Itera su ciascun BQ_bin
    for i, quality in enumerate(all_bins[:4]):  # mostra i primi 4 bin (modificabile)
        ax_i = axes[i]
        for j, (tech_name, tech_df) in enumerate(dfs.items()):
            sub = tech_df[tech_df["BQ_bin"] == quality].sort_values("Cycle")
            if not sub.empty:
                ax_i.plot(
                    sub["Cycle"],
                    sub["identity_with_ins_filtered"] * 100,
                    label=tech_name,
                    color=colori_matplotlib[j % len(colori_matplotlib)],
                    # color=colors[j % len(colors)],
                    linewidth=0.5,
                    marker='o',
                    markersize=2,
                    alpha=0.7
                )
        ax_i.set_title(f"Identity {quality} bin")
        ax_i.set_xlabel("Cycle")
        ax_i.set_ylabel("Identity (%)")
        ax_i.grid(True, alpha=0.3)

    # Crea una legenda unica in basso
    fig.legend(
        tech_dfs.keys(),
        loc="lower center",
        ncol=len(tech_dfs),
        fontsize=10,
        frameon=True
    )

    # Migliora il layout complessivo
    plt.tight_layout(rect=[0, 0.05, 1, 1])  # lascia spazio per la legenda sotto

# %%
# Dizionario con i dataframe e il nome della tecnologia (R1 e R2)
R1 = {
    "Illumina NovaSeq X": df_tot_ns_R1,
    "Element AVITI": df_tot_elm_R1,
    "GeneMind SurfSeq 5000": df_tot_gm_R1,
    "MGI T1": df_tot_mgi_R1
}

R2 = {
    "Illumina NovaSeq X": df_tot_ns_R2,
    "Element AVITI": df_tot_elm_R2,
    "GeneMind SurfSeq 5000": df_tot_gm_R2,
    "MGI T1": df_tot_mgi_R2
}

for dfs in [R1, R2]:
    # Trova tutti i BQ_bin disponibili (assumendo che siano simili tra i dataframe)
    all_bins = sorted(
        set().union(*[df["BQ_bin"].unique() for df in dfs.values()]),
        key=lambda x: str(x)
    )
    
    # --- FIGURA CON 2 RIGHE: Qscore (sopra) + % basi (sotto) ---
    fig, axes = plt.subplots(2, 3, figsize=(15, 7), sharex='col')
    axes_qscore = axes[0]
    axes_bases = axes[1]
    
    for i, quality in enumerate(all_bins[:3]):  # usa i primi 3 bin
        ax_q = axes_qscore[i]
        ax_b = axes_bases[i]
        
        for j, (tech_name, tech_df) in enumerate(dfs.items()):
            sub = tech_df[tech_df["BQ_bin"] == quality].sort_values("Cycle")
            if not sub.empty:
                # Calcola Qscore basato sull'identità
                qscore = -10 * np.log10(1 - sub["identity_with_ins_filtered"])
                
                # Calcola numero di basi e normalizza in %
                num_bases = sub["match"] + sub["mismatch"] + sub["insertion"]
                total_bases_bin = num_bases.sum()
                num_bases_pct = 100 * (num_bases / total_bases_bin)

                color = colori_matplotlib[j % len(colori_matplotlib)]
                
                # --- Riga superiore: Qscore ---
                ax_q.plot(
                    sub["Cycle"],
                    qscore,
                    label=tech_name,
                    color=color,
                    linewidth=0.8,
                    marker='o',
                    markersize=2,
                    alpha=0.8
                )

                # --- Riga inferiore: % basi per ciclo ---
                ax_b.plot(
                    sub["Cycle"],
                    num_bases_pct,
                    color=color,
                    linewidth=0.8,
                    marker='^',
                    markersize=3,
                    alpha=0.6
                )
        
        # Etichette e stile
        ax_q.set_title(f"Sequencer Qscore {quality} bin")
        ax_q.set_ylabel("Identity-based Qscore")
        ax_b.set_xlabel("Cycle")
        ax_q.grid(True, alpha=0.3)
        ax_b.grid(True, alpha=0.3)
        ax_q.tick_params(axis='x', labelbottom=True)
        ax_b.tick_params(axis='x', labelbottom=True)
        ax_b.set_ylim(0.1, 1.1)  # la somma totale del bin = 1

        if quality == "0-19":
            ax_b.set_title(f"Low Qscore Bin ({quality})")
        elif quality == "20-29":
            ax_b.set_title(f"Medium Qscore Bin ({quality})")
        else:
            ax_b.set_title(f"High Qscore Bin ({quality})")
        ax_b.set_ylabel("Fraction of bases per cycle (%)")

        # # Range personalizzato per Qscore
        # if quality == "0-19":
        #     ax_q.set_ylim(0, 19)
        # elif quality == "20-29":
        #     ax_q.set_ylim(20, 32)
        # elif quality == "30+":
        #     ax_q.set_ylim(30, 43)
        # else:
        #     ax_q.set_ylim(0, 43)

        ax_q.set_ylim(0, 43)
        # ax_b.set_ylim(0, 100)  # 0–100% per chiarezza
    
    # --- Legenda globale (una sola per tutti i subplot) ---
    lines, labels = [], []
    for ax_i in axes_qscore:
        line, label = ax_i.get_legend_handles_labels()
        lines.extend(line)
        labels.extend(label)
    
    fig.legend(
        lines[:len(dfs)],
        labels[:len(dfs)],
        loc="lower center",
        ncol=len(dfs),
        fontsize=10,
        frameon=True
    )

    plt.tight_layout(rect=[0, 0.05, 1, 1])
    plt.show()

# %%
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np

results = {}

for tech_name, tech_df in tech_dfs.items():

    df = tech_df.copy()
    df["Q"] = -10 * np.log10(1 - df["identity_with_ins_filtered"])
    df = df.replace([np.inf, -np.inf], np.nan).dropna(subset=["Q"])

    # Modello con interazione
    model = smf.ols("Q ~ Cycle * C(BQ_bin)", data=df).fit()

    # Trova i bin
    bins = sorted(df["BQ_bin"].unique(), key=str)
    ref_bin = bins[0]

    tech_slopes = {}
    tech_pvalues = {}

    # --- Slope + pvalue per il bin di riferimento ---
    base_slope = model.params["Cycle"]
    base_pvalue = model.pvalues["Cycle"]

    tech_slopes[ref_bin] = base_slope
    tech_pvalues[ref_bin] = base_pvalue

    # --- Slopes e pvalue per gli altri bin ---
    for b in bins[1:]:
        term = f"Cycle:C(BQ_bin)[T.{b}]"

        slope = base_slope + model.params.get(term, 0)
        pval = model.pvalues.get(term, np.nan)

        tech_slopes[b] = slope
        tech_pvalues[b] = pval

    # Interpretazione qualitativa
    interpretation = {
        b: (
            "Crescente" if s > 0.01
            else "Decrescente" if s < -0.01
            else "Stabile"
        )
        for b, s in tech_slopes.items()
    }

    # Costruzione tabella
    results[tech_name] = pd.DataFrame({
        "Slope": tech_slopes,
        "p-value": tech_pvalues,
        "Interpretazione": interpretation
    })

# --- Output ---
for tech, df_res in results.items():
    print("\n###", tech)
    print(df_res)
# Out:
# ### Illumina NovaSeq X
#           Slope   p-value Interpretazione
# 0-19  -0.007717  0.000110         Stabile
# 20-29 -0.003600  0.141738         Stabile
# 30+   -0.003941  0.177728         Stabile
#
# ### Element AVITI
#           Slope       p-value Interpretazione
# 0-19  -0.010535  5.867038e-11     Decrescente
# 20-29 -0.014850  5.255673e-02     Decrescente
# 30+   -0.009238  5.590832e-01         Stabile
#
# ### GeneMind SurfSeq 5000
#           Slope   p-value Interpretazione
# 0-19  -0.002132  0.382314         Stabile
# 20-29 -0.006177  0.241410         Stabile
# 30+    0.010198  0.000387       Crescente
#
# ### MGI T1
#           Slope       p-value Interpretazione
# 0-19   0.001035  4.045748e-01         Stabile
# 20-29 -0.014352  3.756926e-17     Decrescente
# 30+    0.000432  7.311742e-01         Stabile

# %%
## RICALCOLO MISMATCH RATE E GRAFICO USANDO SAMTOOLS STATS
import pandas as pd
import matplotlib.pyplot as plt

# --- percorsi dei file samtools stats ---
samtools_stats_elm = "/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/NA12878_KAPA_HCR.samtools.stats"
samtools_stats_ilm = "/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/NA12878_KAPA_HCR.samtools.stats"
samtools_stats_gm = "/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/NA12878_KAPA_HCR.samtools.stats"
samtools_stats_mgi = "/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/NA12878_KAPA_HCR.samtools.stats"

files = {
    "Illumina": samtools_stats_ilm,
    "Element": samtools_stats_elm,
    "GeneMind": samtools_stats_gm,
    "MGI": samtools_stats_mgi,
}

platform_dfs = {}

for platform, path in files.items():

    # --- basi per ciclo (FFQ + LFQ) ---
    bases_rows = []
    mismatch_rows = []

    with open(path) as f:
        for line in f:
            if line.startswith("FFQ") or line.startswith("LFQ"):
                parts = line.strip().split("\t")
                cycle = int(parts[1])
                counts = list(map(int, parts[2:]))
                bases_rows.append((cycle, sum(counts)))
            if line.startswith("MPC"):
                mm_parts = line.strip().split("\t")
                mm_cycle = int(mm_parts[1])
                mm_counts = list(map(int, mm_parts[2:]))
                mismatch_rows.append((mm_cycle, sum(mm_counts)))

    df_bases = pd.DataFrame(bases_rows, columns=["Cycle", "Total_Bases"])
    df_bases = df_bases.groupby("Cycle", observed=False).sum().reset_index()
    df_mm = pd.DataFrame(mismatch_rows, columns=["Cycle", "Total_Mismatches"])
    df_mm["mm_rate"] = (df_mm["Total_Mismatches"] / df_bases["Total_Bases"]) * 100

    df_mm.drop(columns=["Total_Mismatches"], inplace=True)
    # --- aggiungi la colonna piattaforma e salva il df ---

    df_mm["platform"] = platform
    platform_dfs[platform] = df_mm

# --- dopo il loop su tutte le piattaforme, crea il plot ---
fig, ax = plt.subplots(figsize=(7, 5))

for j, (platform, df) in enumerate(platform_dfs.items()):
    # rolling smoothing 5 cicli, center=True
    rolling = df["mm_rate"].rolling(window=5, center=True, min_periods=1).mean()
    ax.plot(df["Cycle"], rolling, label=platform, linewidth=1, marker='o', markersize=2, color = colori_matplotlib[j % len(colori_matplotlib)])

ax.set_title("Mismatch rate per cycle (samtools stats, R1+R2)")
ax.set_xlabel("Cycle")
ax.set_ylabel("Mismatch rate (%)")
ax.grid(True, alpha=0.3)
ax.set_ylim(0, 0.8)
ax.legend()
plt.tight_layout()
plt.show()


samtools_stats_elm_R1 = "/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/NA12878_KAPA_HCR.R1.samtools.stats"
samtools_stats_ilm_R1 = "/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/NA12878_KAPA_HCR.R1.samtools.stats"
samtools_stats_gm_R1 = "/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/NA12878_KAPA_HCR.R1.samtools.stats"
samtools_stats_mgi_R1 = "/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/NA12878_KAPA_HCR.R1.samtools.stats"

samtools_stats_elm_R2 = "/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/NA12878_KAPA_HCR.R2.samtools.stats"
samtools_stats_ilm_R2 = "/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/NA12878_KAPA_HCR.R2.samtools.stats"
samtools_stats_gm_R2 = "/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/NA12878_KAPA_HCR.R2.samtools.stats"
samtools_stats_mgi_R2 = "/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_HCR_common_GATK/NA12878_KAPA/NA12878_KAPA_HCR.R2.samtools.stats"

# -------- file organizzati per piattaforma e read --------
files = {
    "Illumina": {
        "R1": samtools_stats_ilm_R1,
        "R2": samtools_stats_ilm_R2,
    },
    "Element": {
        "R1": samtools_stats_elm_R1,
        "R2": samtools_stats_elm_R2,
    },
    "GeneMind": {
        "R1": samtools_stats_gm_R1,
        "R2": samtools_stats_gm_R2,
    },
    "MGI": {
        "R1": samtools_stats_mgi_R1,
        "R2": samtools_stats_mgi_R2,
    },
}

platform_dfs = {}

# -------- funzione di parsing di un singolo samtools stats --------
def parse_samtools_stats(path):
    bases_rows = []
    mismatch_rows = []

    with open(path) as f:
        for line in f:
            if line.startswith(("FFQ", "LFQ")):
                parts = line.rstrip().split("\t")
                cycle = int(parts[1])
                counts = list(map(int, parts[2:]))
                bases_rows.append((cycle, sum(counts)))

            elif line.startswith("MPC"):
                parts = line.rstrip().split("\t")
                cycle = int(parts[1])
                counts = list(map(int, parts[2:]))
                mismatch_rows.append((cycle, sum(counts)))

    df_bases = (
        pd.DataFrame(bases_rows, columns=["Cycle", "Total_Bases"])
        .groupby("Cycle", observed=False)
        .sum()
        .reset_index()
    )

    df_mm = pd.DataFrame(mismatch_rows, columns=["Cycle", "Total_Mismatches"])

    df = df_mm.merge(df_bases, on="Cycle", how="inner")
    df["mm_rate"] = 100 * df["Total_Mismatches"] / df["Total_Bases"]

    return df[["Cycle", "mm_rate"]]


# -------- loop principale --------
for platform, reads in files.items():

    df_r1 = parse_samtools_stats(reads["R1"])
    df_r2 = parse_samtools_stats(reads["R2"])

    # offset dei cicli R2
    r1_len = df_r1["Cycle"].max()
    df_r2["Cycle"] += r1_len

    df = pd.concat([df_r1, df_r2], ignore_index=True)
    df["platform"] = platform

    platform_dfs[platform] = df


# -------- plotting --------
fig, ax = plt.subplots(figsize=(7, 5))

for j, (platform, df) in enumerate(platform_dfs.items()):
    smoothed = (
        df["mm_rate"]
        .rolling(window=5, center=True, min_periods=1)
        .mean()
    )
    ax.plot(df["Cycle"], smoothed, label=platform, linewidth=1, marker='o', markersize=2, color = colori_matplotlib[j % len(colori_matplotlib)])

# linea di separazione R1 / R2
r1_length = next(iter(platform_dfs.values()))["Cycle"].max() // 2
ax.axvline(x=150, color="k", linestyle="--", alpha=0.6)

ax.set_title("Identity-based mismatch rate per cycle (samtools stats)")
ax.set_xlabel("Cycle")
ax.set_ylabel("Mismatch rate (%)")
ax.grid(True, alpha=0.3)
ax.legend(title="Technology")
ax.set_ylim(0, 0.8)

plt.tight_layout()
plt.show()
