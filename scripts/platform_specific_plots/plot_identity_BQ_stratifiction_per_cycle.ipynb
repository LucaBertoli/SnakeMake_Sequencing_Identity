# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_cycle_gm_V1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle.by_cycle_only.tsv", delimiter="\t")
df_cycle_gm_V2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_MGI_G400 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_MGI_T1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")

df_cycle_gm_V1_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read1.by_cycle_only.tsv", delimiter="\t")
df_cycle_gm_V2_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_MGI_G400_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_cycle_only.tsv", delimiter="\t")
df_cycle_MGI_T1_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_gm_V1_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read2.by_cycle_only.tsv", delimiter="\t")
df_cycle_gm_V2_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")
df_cycle_MGI_G400_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_cycle_only.tsv", delimiter="\t")
df_cycle_MGI_T1_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv.by_cycle_only.tsv", delimiter="\t")

df_gm_V1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle.by_NEW_bin_cycle.tsv", delimiter="\t")
df_gm_V2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_mgi_G400 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_mgi_T1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")

df_tot_gm_V1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle.by_quality_cycle.tsv", delimiter="\t")
df_tot_gm_V2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv", delimiter="\t")
df_tot_mgi_G400 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv", delimiter="\t")
df_tot_mgi_T1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv", delimiter="\t")

df_tot_noBin_gm_V1_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read1.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_gm_V2_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_mgi_G400_R1=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_mgi_T1_R1=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_gm_V1_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read2.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_gm_V2_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_mgi_G400_R2=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv", delimiter="\t")
df_tot_noBin_mgi_T1_R2=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv", delimiter="\t")

df_tot_gm_V1_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read1.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_gm_V2_R1 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_mgi_G400_R1=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_mgi_T1_R1=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_gm_V1_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read2.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_gm_V2_R2 = pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_mgi_G400_R2=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")
df_tot_mgi_T1_R2=pd.read_csv("/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv.by_NEW_bin_cycle.tsv", delimiter="\t")


colori_matplotlib = [
    "r", "b", "g", "c", "m", "y", "k",
    "royalblue", "limegreen", "tomato", "deepskyblue", "darkorchid", "goldenrod", "dimgray",
    "dodgerblue", "springgreen", "salmon", "skyblue", "mediumorchid", "khaki", "lightgray",
    "cornflowerblue", "palegreen", "lightcoral", "lightcyan", "lightpink", "lightyellow", "silver",
    "steelblue", "springgreen", "lightsalmon", "powderblue", "mediumvioletred", "gold", "gainsboro",
    "cornflowerblue", "chartreuse", "darkorange", "cadetblue", "mediumslateblue", "darkkhaki", "beige",
    "mediumblue", "mediumseagreen", "crimson", "darkturquoise", "darkslategray", "olive", "floralwhite",
    "mediumslateblue", "chartreuse", "darkorange", "cadetblue", "mediumslateblue", "darkkhaki", "beige",
]

# %%
tech_dfs = {
    "GeneMind V1": df_tot_gm_V1,
    "GeneMind V2": df_tot_gm_V2,
    # "MGI G400": df_tot_mgi_G400,
    # "MGI T1": df_tot_mgi_T1
}

tech_dfs_1 = {
    "GeneMind V1": df_tot_noBin_gm_V1_R1,
    "GeneMind V2": df_tot_noBin_gm_V2_R1,
    # "MGI G400": df_tot_noBin_mgi_G400_R1,
    # "MGI T1": df_tot_noBin_mgi_T1_R1
}

tech_dfs_2 = {
    "GeneMind V1": df_tot_noBin_gm_V1_R2,
    "GeneMind V2": df_tot_noBin_gm_V2_R2,
    # "MGI G400": df_tot_noBin_mgi_G400_R2,
    # "MGI T1": df_tot_noBin_mgi_T1_R2
}

tutti_tech_dfs = [tech_dfs, tech_dfs_1, tech_dfs_2]

for i, dfs in enumerate(tutti_tech_dfs):

    if i == 0:
        mode = ""
    elif i == 1:
        mode = " Read 1"
    else:
        mode = " Read 2"

    print(f"Plot gruppo {i}{mode}")

    # --- CALCOLA QUALITÀ MEDIA PER CICLO ---
    tech_cycle_quality = {}

    for tech_name, df in dfs.items():

        # Evita di modificare il dataframe originale
        df_local = df.copy()

        # Calcola totale basi
        df_local["total_bases"] = df_local["match"] + df_local["mismatch"] + df_local["insertion"]

        # Raggruppa per ciclo e calcola la media pesata del Qscore
        grouped = (
            df_local.groupby("Cycle", observed=False)
                .apply(lambda x: (
                    -10 * np.log10(
                        np.average(10 ** (-x["BaseQuality"] / 10), weights=x["total_bases"])
                    )
                    if x["total_bases"].sum() > 0 else np.nan
                ))
                .reset_index(name="mean_BaseQuality")
        )

        tech_cycle_quality[tech_name] = grouped

    # --- PLOT ---
    fig, ax = plt.subplots(figsize=(8, 5))

    for j, (tech_name, grouped) in enumerate(tech_cycle_quality.items()):
        ax.plot(
            grouped["Cycle"],
            grouped["mean_BaseQuality"],
            label=tech_name,
            color=colori_matplotlib[j % len(colori_matplotlib)],
            linewidth=0.8,
            marker='o',
            markersize=2,
            alpha=0.8
        )

    # Titolo
    ax.set_title(
        f"Sequencer-assigned Qscore per Cycle{mode} (logarithm of mean error probability)"
    )

    # Assi
    ax.set_xlabel("Cycle")
    ax.set_ylabel("Mean Qscore")
    ax.grid(True, alpha=0.3)
    ax.set_ylim(0, 43)

    # Legenda globale sotto il grafico
    fig.legend(
        tech_cycle_quality.keys(),
        loc="lower center",
        ncol=len(tech_cycle_quality),
        fontsize=10,
        frameon=True
    )

    plt.tight_layout(rect=[0, 0.05, 1, 1])
    plt.show()
# Out:
# Plot gruppo 0
# Plot gruppo 1 Read 1
# Plot gruppo 2 Read 2

# %%
# Tre gruppi di dataframe
tech_dfs_0 = {
    "GeneMind V1": df_cycle_gm_V1,
    "GeneMind V2": df_cycle_gm_V2,
    # "MGI G400": df_cycle_MGI_G400,
    # "MGI T1": df_cycle_MGI_T1,
}

tech_dfs_1 = {
    "GeneMind V1": df_cycle_gm_V1_R1,
    "GeneMind V2": df_cycle_gm_V2_R1,
    # "MGI G400": df_cycle_MGI_G400_R1,
    # "MGI T1": df_cycle_MGI_T1_R1
}

tech_dfs_2 = {
    "GeneMind V1": df_cycle_gm_V1_R2,
    "GeneMind V2": df_cycle_gm_V2_R2,
    # "MGI G400": df_cycle_MGI_G400_R2,
    # "MGI T1": df_cycle_MGI_T1_R2
}

# Lista dei gruppi
tutti_tech_dfs = [tech_dfs_0, tech_dfs_1, tech_dfs_2]

# Loop sui 3 insiemi
for i, dfs in enumerate(tutti_tech_dfs):

    # Titolo per la figura
    if i == 0:
        mode = ""
    elif i == 1:
        mode = " Read 1"
    else:
        mode = " Read 2"

    print(f"Plot Identity-based Qscore {mode}")

    # --- FIGURA ---
    fig, ax = plt.subplots(figsize=(8, 5))

    for j, (tech_name, tech_df) in enumerate(dfs.items()):

        # Evita di modificare i dataframe originali
        sub = tech_df.copy().sort_values("Cycle")

        if not sub.empty:
            # Conversione identity → Qscore
            qscore = -10 * np.log10(1 - sub["identity_with_ins_filtered"])

            ax.plot(
                sub["Cycle"],
                qscore,
                label=tech_name,
                color=colori_matplotlib[j % len(colori_matplotlib)],
                linewidth=0.8,
                marker='o',
                markersize=2,
                alpha=0.8
            )

    # Etichette e formattazione
    ax.set_title(f"Identity-based Qscore per Cycle{mode}")
    ax.set_xlabel("Cycle")
    ax.set_ylabel("Qscore")
    ax.grid(True, alpha=0.3)
    ax.set_ylim(0, 43)

    # Legenda sotto
    fig.legend(
        dfs.keys(),
        loc="lower center",
        ncol=len(dfs),
        fontsize=10,
        frameon=True
    )

    plt.tight_layout(rect=[0, 0.05, 1, 1])
    plt.show()
# Out:
# Plot Identity-based Qscore
# Plot Identity-based Qscore  Read 1
# Plot Identity-based Qscore  Read 2

# %%
# Dizionario con i dataframe e il nome della tecnologia
tech_dfs = {
    "GeneMind V1": df_gm_V1,
    "GeneMind V2": df_gm_V2,
    # "MGI G400": df_mgi_G400,
    # "MGI T1": df_mgi_T1
}
 
# Trova tutti i BQ_bin disponibili (assumendo che siano simili tra i dataframe)
all_bins = sorted(
    set().union(*[df["BQ_bin"].unique() for df in tech_dfs.values()]),
    key=lambda x: str(x)
)

# --- FIGURA CON DUE RIGHE DI SUBPLOT (3 col x 2 righe) ---
fig, axes = plt.subplots(2, 3, figsize=(15, 8), sharex='col')
axes_qscore = axes[0]
axes_bases = axes[1]

for i, quality in enumerate(all_bins[:3]):  # usa i primi 3 bin
    ax_q = axes_qscore[i]
    ax_b = axes_bases[i]

    for j, (tech_name, tech_df) in enumerate(tech_dfs.items()):
        sub = tech_df[tech_df["BQ_bin"] == quality].sort_values("Cycle").copy()
        if not sub.empty:
            # Calcolo Qscore (basato su identità)
            qscore = -10 * np.log10(1 - sub["identity_with_ins_filtered"])

            # Numero totale di basi per ciclo
            num_bases = sub["match"] + sub["mismatch"] + sub["insertion"]

            # ✅ Normalizza sul totale di quella tecnologia e bin
            total_bases_bin = num_bases.sum()
            num_bases_norm = (num_bases / total_bases_bin)*100

            color = colori_matplotlib[j % len(colori_matplotlib)]

            # --- Riga superiore: Qscore (identità per ciclo) ---
            ax_q.plot(
                sub["Cycle"],
                qscore,
                label=tech_name,
                color=color,
                linewidth=0.8,
                marker='o',
                markersize=2,
                alpha=0.8
            )

            # --- Riga inferiore: frazione di basi normalizzata ---
            ax_b.plot(
                sub["Cycle"],
                num_bases_norm,
                color=color,
                linewidth=0.8,
                marker='^',
                markersize=3,
                alpha=0.6
            )

    # --- Etichette e titoli ---
    ax_q.set_title(f"Sequencer Qscore {quality} bin")
    ax_q.set_ylabel("Identity-based Qscore")
    ax_b.set_xlabel("Cycle")
    ax_b.set_ylabel("Fraction of bases per cycle (%)")
    ax_q.grid(True, alpha=0.3)
    ax_b.grid(True, alpha=0.3)
    # ax_b.set_ylim(0, 2)  # la somma totale del bin = 1

    # Range personalizzati per Qscore
    ax_q.set_ylim(0, 43)

# --- Legenda globale (solo Qscore) ---
lines, labels = [], []
for ax_i in axes_qscore:
    line, label = ax_i.get_legend_handles_labels()
    lines.extend(line)
    labels.extend(label)

fig.legend(
    lines[:len(tech_dfs)],
    labels[:len(tech_dfs)],
    loc="lower center",
    ncol=len(tech_dfs),
    fontsize=10,
    frameon=True,
)

plt.tight_layout(rect=[0, 0.05, 1, 1])
plt.show()

# %%
# Dizionario con i dataframe e il nome della tecnologia (R1 e R2)
R1 = {
    # "GeneMind V1": df_tot_gm_V1_R1,
    # "GeneMind V2": df_tot_gm_V2_R1,
    "MGI G400": df_tot_mgi_G400_R1,
    "MGI T1": df_tot_mgi_T1_R1
}

R2 = {
    # "GeneMind V1": df_tot_gm_V1_R2,
    # "GeneMind V2": df_tot_gm_V2_R2,
    "MGI G400": df_tot_mgi_G400_R2,
    "MGI T1": df_tot_mgi_T1_R2
}

for dfs in [R1, R2]:
    # Trova tutti i BQ_bin disponibili (assumendo che siano simili tra i dataframe)
    all_bins = sorted(
        set().union(*[df["BQ_bin"].unique() for df in dfs.values()]),
        key=lambda x: str(x)
    )
    
    # --- FIGURA CON 2 RIGHE: Qscore (sopra) + % basi (sotto) ---
    fig, axes = plt.subplots(2, 3, figsize=(15, 7), sharex='col')
    axes_qscore = axes[0]
    axes_bases = axes[1]
    
    for i, quality in enumerate(all_bins[:3]):  # usa i primi 3 bin
        ax_q = axes_qscore[i]
        ax_b = axes_bases[i]
        
        for j, (tech_name, tech_df) in enumerate(dfs.items()):
            sub = tech_df[tech_df["BQ_bin"] == quality].sort_values("Cycle")
            if not sub.empty:
                # Calcola Qscore basato sull'identità
                qscore = -10 * np.log10(1 - sub["identity_with_ins_filtered"])
                
                # Calcola numero di basi e normalizza in %
                num_bases = sub["match"] + sub["mismatch"] + sub["insertion"]
                total_bases_bin = num_bases.sum()
                num_bases_pct = 100 * (num_bases / total_bases_bin)

                color = colori_matplotlib[j % len(colori_matplotlib)]
                
                # --- Riga superiore: Qscore ---
                ax_q.plot(
                    sub["Cycle"],
                    qscore,
                    label=tech_name,
                    color=color,
                    linewidth=0.8,
                    marker='o',
                    markersize=2,
                    alpha=0.8
                )

                # --- Riga inferiore: % basi per ciclo ---
                ax_b.plot(
                    sub["Cycle"],
                    num_bases_pct,
                    color=color,
                    linewidth=0.8,
                    marker='^',
                    markersize=3,
                    alpha=0.6
                )
        
        # Etichette e stile
        ax_q.set_title(f"Sequencer Qscore {quality} bin")
        ax_q.set_ylabel("Identity-based Qscore")
        ax_b.set_xlabel("Cycle")
        ax_b.set_ylabel("Fraction of bases per cycle (%)")
        ax_q.grid(True, alpha=0.3)
        ax_b.grid(True, alpha=0.3)
        ax_q.tick_params(axis='x', labelbottom=True)
        ax_b.tick_params(axis='x', labelbottom=True)

        # # Range personalizzato per Qscore

        ax_q.set_ylim(0, 43)
    
    # --- Legenda globale (una sola per tutti i subplot) ---
    lines, labels = [], []
    for ax_i in axes_qscore:
        line, label = ax_i.get_legend_handles_labels()
        lines.extend(line)
        labels.extend(label)
    
    fig.legend(
        lines[:len(dfs)],
        labels[:len(dfs)],
        loc="lower center",
        ncol=len(dfs),
        fontsize=10,
        frameon=True
    )

    plt.tight_layout(rect=[0, 0.05, 1, 1])
    plt.show()
