# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
element_tsv = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat.tsv.gz.stats'
illumina_tsv = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat.tsv.gz.stats'
# genemind_tsv = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat.tsv.gz.stats'
genemind_tsv = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification.tsv.gz.stats'
# MGI_tsv = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification.tsv.gz.stats'
MGI_tsv = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification.tsv.gz.stats'

tsvs_quality = [illumina_tsv, element_tsv, genemind_tsv, MGI_tsv]

element_cycle_tsv = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat_cycle'
illumina_cycle_tsv = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle'
# genemind_cycle_tsv = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V1/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle'
genemind_cycle_tsv = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv'
# MGI_cycle_tsv = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv'
MGI_cycle_tsv = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle.tsv'

tsvs_quality_cycle = [illumina_cycle_tsv, element_cycle_tsv, genemind_cycle_tsv, MGI_cycle_tsv]

element_cycle_tsv_R1 = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat_cycle_read1'
illumina_cycle_tsv_R1 = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle_read1'
# genemind_cycle_tsv_R1 = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read1'
genemind_cycle_tsv_R1 = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv'
# MGI_cycle_tsv_R1 = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv'
MGI_cycle_tsv_R1 = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read1.by_quality_cycle.tsv'

element_cycle_tsv_R2 = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/Element_WGS/RUN_4/IDENTITY_NA12878_Element_run4_GIAB_basequal_strat_cycle_read2'
illumina_cycle_tsv_R2 = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/ILLUMINA_NovaSeqX_WGS/NA12878_KAPA/IDENTITY_NA12878_NovaSeqX_KAPA_GIAB_basequal_strat_cycle_read2'
# genemind_cycle_tsv_R2 = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/IDENTITY_NA12878_GeneMind_GIAB_basequal_strat_cycle_read2'
genemind_cycle_tsv_R2 = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/GeneMind_WGS/V2/SnakeMake_Sequencing_Identity/NA12878_KAPA/IDENTITY_NA12878_KAPA_full_all_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv'
# MGI_cycle_tsv_R2 = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/G400/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv'
MGI_cycle_tsv_R2 = '/home/comparazione_kit/calcolo_identità_sequenze_Sequenziatori/MGI/T1/SnakeMake_Sequencing_Identity_results/NA12878_KAPA/IDENTITY_NA12878_KAPA_base_quality_stratification_by_quality_cycle_read2.by_quality_cycle.tsv'

tsvs_quality_cycle_R1_R2 = [illumina_cycle_tsv_R1, element_cycle_tsv_R1, genemind_cycle_tsv_R1, MGI_cycle_tsv_R1, illumina_cycle_tsv_R2, element_cycle_tsv_R2, genemind_cycle_tsv_R2, MGI_cycle_tsv_R2]

# %%
#creazione binning corretto per identità stratificata per base
for i in tsvs_quality:
    df = pd.read_csv(i, sep="\t")
    bins = [0, 20, 30, 51]
    labels = ['0-19', '20-29', '30+']
    df['BQ_bin'] = pd.cut(df['BaseQuality'], bins=bins, labels=labels, right=False)

    binned_stats = df.groupby('BQ_bin', observed=False).agg({
        'Match': 'sum',
        'Match_correct': 'sum',
        'Match_error': 'sum',
        'Mismatch': 'sum',
        'Mismatch_correct': 'sum',
        'Mismatch_error': 'sum',
        'Insertion': 'sum',
        'Insertion_correct': 'sum',
        'Insertion_error': 'sum'
    }).reset_index()

    binned_stats['identity'] = 1 - (binned_stats['Mismatch'] / (binned_stats['Match'] + binned_stats['Mismatch']))
    binned_stats['identity_filtered'] = 1 - ((binned_stats['Mismatch_error']) / (binned_stats['Match'] + binned_stats['Mismatch']))
    binned_stats['identity_with_ins'] = 1 - ((binned_stats['Mismatch'] + binned_stats['Insertion']) / (binned_stats['Match'] + binned_stats['Mismatch'] + binned_stats['Insertion']))
    binned_stats['identity_with_ins_filtered'] = 1 - ((binned_stats['Mismatch_error'] + binned_stats["Insertion_error"]) / (binned_stats['Match'] + binned_stats['Mismatch'] + binned_stats['Insertion']))
    binned_stats.to_csv(i + ".NEW.binned.stats", sep="\t", index=False, float_format="%.6f", na_rep="NaN")

# %%
#creazione binning corretto per identità stratificata per ciclo
for i in tsvs_quality_cycle:    
    if not i.endswith(".tsv"):
        df = pd.read_csv(i + ".by_quality_cycle.tsv", sep="\t")
    else:
        df = pd.read_csv(i, sep="\t")

    grouped = df.groupby(['Cycle'], observed=False).agg({
        'match': 'sum',
        'match_correct': 'sum',
        'match_error': 'sum',
        'mismatch': 'sum',
        'mismatch_correct': 'sum',
        'mismatch_error': 'sum',
        'insertion': 'sum',
        'insertion_correct': 'sum',
        'insertion_error': 'sum'
    }).reset_index()

    total = grouped['match'] + grouped['mismatch']
    total_all = grouped['match'] + grouped['mismatch'] + grouped['insertion']
    grouped['identity'] = 1 - (grouped['mismatch'] / total)
    grouped['identity_filtered'] = 1 - (grouped['mismatch_error'] / total)
    grouped['identity_with_ins'] = 1 - ((grouped['mismatch'] + grouped['insertion']) / total_all)
    grouped['identity_with_ins_filtered'] = 1 - ((grouped['mismatch_error'] + grouped['insertion_error']) / total_all)

    grouped = grouped.sort_values(by=['Cycle'])
    grouped.to_csv(i + ".by_cycle_only.tsv", sep="\t", index=False, float_format="%.6f", na_rep="NaN")

# %%
#creazione binning corretto per identità stratificata per base e per ciclo
for i in tsvs_quality_cycle:    
    if not i.endswith(".tsv"):
        df = pd.read_csv(i + ".by_quality_cycle.tsv", sep="\t")
    else:
        df = pd.read_csv(i, sep="\t")
    bins = [0, 20, 30, 51]
    labels = ['0-19', '20-29', '30+']
    df['BQ_bin'] = pd.cut(df['BaseQuality'], bins=bins, labels=labels, right=False)

    grouped = df.groupby(['BQ_bin','Cycle'], observed=False).agg({
        'match': 'sum',
        'match_correct': 'sum',
        'match_error': 'sum',
        'mismatch': 'sum',
        'mismatch_correct': 'sum',
        'mismatch_error': 'sum',
        'insertion': 'sum',
        'insertion_correct': 'sum',
        'insertion_error': 'sum'
    }).reset_index()

    total = grouped['match'] + grouped['mismatch']
    total_all = grouped['match'] + grouped['mismatch'] + grouped['insertion']
    grouped['identity'] = 1 - (grouped['mismatch'] / total)
    grouped['identity_filtered'] = 1 - (grouped['mismatch_error'] / total)
    grouped['identity_with_ins'] = 1 - ((grouped['mismatch'] + grouped['insertion']) / total_all)
    grouped['identity_with_ins_filtered'] = 1 - ((grouped['mismatch_error'] + grouped['insertion_error']) / total_all)

    grouped = grouped.sort_values(by=['BQ_bin','Cycle'])
    grouped.to_csv(i + ".by_NEW_bin_cycle.tsv", sep="\t", index=False, float_format="%.6f", na_rep="NaN")

# %%
#creazione binning corretto per identità stratificata per base e per ciclo (R1 e R2 separati)
for i in tsvs_quality_cycle_R1_R2:    
    if not i.endswith(".tsv"):
        df = pd.read_csv(i + ".by_quality_cycle.tsv", sep="\t")
    else:
        df = pd.read_csv(i, sep="\t")
    bins = [0, 20, 30, 51]
    labels = ['0-19', '20-29', '30+']
    df['BQ_bin'] = pd.cut(df['BaseQuality'], bins=bins, labels=labels, right=False)

    grouped = df.groupby(['BQ_bin','Cycle'], observed=False).agg({
        'match': 'sum',
        'match_correct': 'sum',
        'match_error': 'sum',
        'mismatch': 'sum',
        'mismatch_correct': 'sum',
        'mismatch_error': 'sum',
        'insertion': 'sum',
        'insertion_correct': 'sum',
        'insertion_error': 'sum'
    }).reset_index()

    total = grouped['match'] + grouped['mismatch']
    total_all = grouped['match'] + grouped['mismatch'] + grouped['insertion']
    grouped['identity'] = 1 - (grouped['mismatch'] / total)
    grouped['identity_filtered'] = 1 - (grouped['mismatch_error'] / total)
    grouped['identity_with_ins'] = 1 - ((grouped['mismatch'] + grouped['insertion']) / total_all)
    grouped['identity_with_ins_filtered'] = 1 - ((grouped['mismatch_error'] + grouped['insertion_error']) / total_all)

    grouped = grouped.sort_values(by=['BQ_bin','Cycle'])
    grouped.to_csv(i + ".by_NEW_bin_cycle.tsv", sep="\t", index=False, float_format="%.6f", na_rep="NaN")
