# %%
import pandas as pd
import numpy as np
import math

# %%
read = [('T', 39), ('C', 36), ('T', 33), ('C', 35), ('A', 38), ('G', 32), ('C', 28), ('A', 18), ('A', 9), ('G', 36), ('A', 36), ('C', 16), ('A', 12), ('G', 14), ('T', 32), ('A', 9), ('G', 28), ('A', 37), ('A', 29), ('A', 35), ('G', 11), ('A', 14), ('C', 14), ('A', 23), ('G', 28), ('A', 29), ('A', 35), ('C', 13), ('C', 11), ('A', 34), ('G', 38), ('G', 31), ('A', 16), ('G', 34), ('A', 37), ('T', 9), ('A', 9), ('G', 9), ('A', 16), ('G', 14), ('G', 32), ('A', 39), ('G', 39), ('G', 18), ('A', 14), ('G', 35), ('G', 25), ('G', 20), ('T', 29), ('G', 39), ('C', 30), ('T', 34), ('G', 37), ('G', 23), ('A', 21), ('T', 9), ('A', 35), ('T', 32), ('G', 28), ('A', 37), ('A', 36), ('T', 14), ('A', 38), ('G', 32), ('A', 39), ('G', 34), ('A', 28), ('C', 12), ('T', 37), ('G', 27), ('C', 34), ('A', 34), ('G', 29), ('G', 21), ('T', 27), ('G', 39), ('T', 11), ('C', 27), ('T', 12), ('C', 12), ('C', 23), ('T', 39), ('T', 27), ('T', 21), ('C', 36), ('A', 36), ('G', 30), ('G', 30), ('C', 37), ('T', 36), ('G', 16), ('G', 23), ('T', 38), ('C', 11), ('C', 29), ('A', 27), ('G', 32), ('A', 38), ('G', 34), ('C', 30), ('C', 16), ('C', 7), ('C', 38), ('A', 38), ('C', 36), ('A', 16), ('T', 21), ('C', 26), ('T', 30), ('C', 33), ('T', 29), ('T', 39), ('A', 19), ('G', 29), ('T', 33), ('A', 39), ('T', 33), ('G', 34), ('C', 34), ('A', 39), ('C', 32), ('T', 39), ('C', 36), ('A', 32), ('A', 39), ('G', 36), ('T', 34), ('A', 32), ('G', 31), ('A', 39), ('C', 27), ('C', 32), ('A', 34), ('G', 27), ('G', 31), ('G', 36), ('T', 16), ('G', 39), ('A', 18), ('A', 29), ('A', 38), ('A', 38), ('A', 39), ('T', 39), ('T', 36), ('C', 39), ('A', 39), ('A', 35), ('T', 39), ('C', 16)]

print(read)

read_dict = {'base': [item[0] for item in read], 'qualità': [item[1] for item in read]}
print(read_dict)

print("la media delle qualità delle basi è ", np.mean(read_dict['qualità']))

N = len(read_dict['qualità'])
mean_error = sum(10 ** (-q / 10) for q in read_dict['qualità']) / N
Q_average = -10 * math.log10(mean_error)
print(f"l'error rate medio è {mean_error:.4f} e la conseguente qualità è {Q_average:.4f}")

print(f"la lunghezza reale della read è {N}, che contiene 6 mismatch, quindi l'error rate reale è {6/N} e la qualità reale è {-10*math.log10(6/N):.4f}")
# Out:
# [('T', 39), ('C', 36), ('T', 33), ('C', 35), ('A', 38), ('G', 32), ('C', 28), ('A', 18), ('A', 9), ('G', 36), ('A', 36), ('C', 16), ('A', 12), ('G', 14), ('T', 32), ('A', 9), ('G', 28), ('A', 37), ('A', 29), ('A', 35), ('G', 11), ('A', 14), ('C', 14), ('A', 23), ('G', 28), ('A', 29), ('A', 35), ('C', 13), ('C', 11), ('A', 34), ('G', 38), ('G', 31), ('A', 16), ('G', 34), ('A', 37), ('T', 9), ('A', 9), ('G', 9), ('A', 16), ('G', 14), ('G', 32), ('A', 39), ('G', 39), ('G', 18), ('A', 14), ('G', 35), ('G', 25), ('G', 20), ('T', 29), ('G', 39), ('C', 30), ('T', 34), ('G', 37), ('G', 23), ('A', 21), ('T', 9), ('A', 35), ('T', 32), ('G', 28), ('A', 37), ('A', 36), ('T', 14), ('A', 38), ('G', 32), ('A', 39), ('G', 34), ('A', 28), ('C', 12), ('T', 37), ('G', 27), ('C', 34), ('A', 34), ('G', 29), ('G', 21), ('T', 27), ('G', 39), ('T', 11), ('C', 27), ('T', 12), ('C', 12), ('C', 23), ('T', 39), ('T', 27), ('T', 21), ('C', 36), ('A', 36), ('G', 30), ('G', 30), ('C', 37), ('T', 36), ('G', 16), ('
# ...
